# %%
import nest_asyncio
nest_asyncio.apply()
import twint

c = twint.Config()

c.Username = "elonmusk"
c.Store_json = True
c.Output = "../data.json"

twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       2 nest_asyncio.apply()
#       3 import twint
# ----> 5 print(twint.config.__version__);
#       7 # c = twint.Config()
#       8
#       9 # c.Username = "elonmusk"
#    (...)
#      12
#      13 # twint.run.Search(c)
#
# AttributeError: module 'twint' has no attribute 'config'

# %%
import pandas as pd

# %%
data = pd.read_json("../data.json", lines = True)

# %%
data
# Out:
#                       id      conversation_id  \
# 0    1615461396313178115  1615418460540145664
# 1    1615407202780721158  1615134834908856320
# 2    1615406697849442304  1615406697849442304
# 3    1615403742001762304  1615402597862735872
# 4    1615402425514614785  1615398117683388416
# ..                   ...                  ...
# 176  1611139320391544832  1611096634443849728
# 177  1611138353705156609  1610751153440018432
# 178  1611112185895473163  1611112185895473152
# 179  1611111410846814208  1611107762775228416
# 180  1611110531917828097  1611107762775228416
#
#                                   created_at       date      time  timezone  \
# 0    2023-01-18 02:59:45 India Standard Time 2023-01-18  02:59:45       530
# 1    2023-01-17 23:24:24 India Standard Time 2023-01-17  23:24:24       530
# 2    2023-01-17 23:22:24 India Standard Time 2023-01-17  23:22:24       530
# 3    2023-01-17 23:10:39 India Standard Time 2023-01-17  23:10:39       530
# ...
